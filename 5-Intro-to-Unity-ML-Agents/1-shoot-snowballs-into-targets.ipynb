# %% [markdown]
# Clone Repo and install dependencies

# %%
# %%capture
# Clone the Unity ML-Agents Toolkit GitHub repository
# !git clone --depth 1 https://github.com/Unity-Technologies/ml-agents

# %%
# Go inside the repository and install the package
# %cd ml-agents
# !pip3 install -e ./ml-agents-envs
# !pip3 install -e ./ml-agents
# Out:
# /home/raj/repos/HF-DeepRL/5-Intro-to-Unity-ML-Agents/ml-agents
# Obtaining file:///home/raj/repos/HF-DeepRL/5-Intro-to-Unity-ML-Agents/ml-agents/ml-agents-envs
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: cloudpickle in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from mlagents-envs==0.31.0.dev0) (2.2.1)
# Requirement already satisfied: grpcio>=1.11.0 in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from mlagents-envs==0.31.0.dev0) (1.56.0)
# Requirement already satisfied: Pillow>=4.2.1 in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from mlagents-envs==0.31.0.dev0) (10.0.0)
# Requirement already satisfied: protobuf<3.20,>=3.6 in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from mlagents-envs==0.31.0.dev0) (3.19.6)
# Requirement already satisfied: pyyaml>=3.1.0 in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from mlagents-envs==0.31.0.dev0) (6.0)
# Requirement already satisfied: gym>=0.21.0 in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from mlagents-envs==0.31.0.dev0) (0.26.2)
# Requirement already satisfied: pettingzoo==1.15.0 in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from mlagents-envs==0.31.0.dev0) (1.15.0)
# Collecting numpy==1.21.2
#   Using cached numpy-1.21.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.9 MB)
# Requirement already satisfied: filelock>=3.4.0 in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from mlagents-envs==0.31.0.dev0) (3.12.2)
# Requirement already satisfied: gym-notices>=0.0.4 in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from gym>=0.21.0->mlagents-envs==0.31.0.dev0) (0.0.8)
# Installing collected packages: numpy, mlagents-envs
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.25.0
#     Uninstalling numpy-1.25.0:
#       Successfully uninstalled numpy-1.25.0
#   Running setup.py develop for mlagents-envs
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scipy 1.11.1 requires numpy<1.28.0,>=1.21.6, but you have numpy 1.21.2 which is incompatible.
# Successfully installed mlagents-envs-0.31.0.dev0 numpy-1.21.2
# Obtaining file:///home/raj/repos/HF-DeepRL/5-Intro-to-Unity-ML-Agents/ml-agents/ml-agents
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: grpcio>=1.11.0 in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from mlagents==0.31.0.dev0) (1.56.0)
# Requirement already satisfied: h5py>=2.9.0 in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from mlagents==0.31.0.dev0) (3.9.0)
# Requirement already satisfied: mlagents_envs==0.31.0.dev0 in ./ml-agents-envs (from mlagents==0.31.0.dev0) (0.31.0.dev0)
# Requirement already satisfied: numpy<2.0,>=1.13.3 in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from mlagents==0.31.0.dev0) (1.21.2)
# Requirement already satisfied: Pillow>=4.2.1 in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from mlagents==0.31.0.dev0) (10.0.0)
# Requirement already satisfied: protobuf<3.20,>=3.6 in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from mlagents==0.31.0.dev0) (3.19.6)
# Requirement already satisfied: pyyaml>=3.1.0 in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from mlagents==0.31.0.dev0) (6.0)
# Requirement already satisfied: tensorboard>=1.15 in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from mlagents==0.31.0.dev0) (2.13.0)
# Requirement already satisfied: attrs>=19.3.0 in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from mlagents==0.31.0.dev0) (23.1.0)
# Requirement already satisfied: huggingface_hub>=0.14 in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from mlagents==0.31.0.dev0) (0.15.1)
# Requirement already satisfied: torch<=1.11.0,>=1.8.0 in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from mlagents==0.31.0.dev0) (1.11.0+cu113)
# Requirement already satisfied: cattrs<1.7,>=1.1.0 in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from mlagents==0.31.0.dev0) (1.5.0)
# Requirement already satisfied: cloudpickle in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from mlagents_envs==0.31.0.dev0->mlagents==0.31.0.dev0) (2.2.1)
# Requirement already satisfied: gym>=0.21.0 in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from mlagents_envs==0.31.0.dev0->mlagents==0.31.0.dev0) (0.26.2)
# Requirement already satisfied: pettingzoo==1.15.0 in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from mlagents_envs==0.31.0.dev0->mlagents==0.31.0.dev0) (1.15.0)
# Requirement already satisfied: filelock>=3.4.0 in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from mlagents_envs==0.31.0.dev0->mlagents==0.31.0.dev0) (3.12.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from huggingface_hub>=0.14->mlagents==0.31.0.dev0) (4.7.0)
# Requirement already satisfied: tqdm>=4.42.1 in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from huggingface_hub>=0.14->mlagents==0.31.0.dev0) (4.65.0)
# Requirement already satisfied: fsspec in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from huggingface_hub>=0.14->mlagents==0.31.0.dev0) (2023.6.0)
# Requirement already satisfied: requests in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from huggingface_hub>=0.14->mlagents==0.31.0.dev0) (2.31.0)
# Requirement already satisfied: packaging>=20.9 in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from huggingface_hub>=0.14->mlagents==0.31.0.dev0) (23.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from tensorboard>=1.15->mlagents==0.31.0.dev0) (1.0.0)
# Requirement already satisfied: absl-py>=0.4 in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from tensorboard>=1.15->mlagents==0.31.0.dev0) (1.4.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from tensorboard>=1.15->mlagents==0.31.0.dev0) (3.4.3)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from tensorboard>=1.15->mlagents==0.31.0.dev0) (2.3.6)
# Requirement already satisfied: wheel>=0.26 in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from tensorboard>=1.15->mlagents==0.31.0.dev0) (0.40.0)
# Requirement already satisfied: setuptools>=41.0.0 in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from tensorboard>=1.15->mlagents==0.31.0.dev0) (68.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from tensorboard>=1.15->mlagents==0.31.0.dev0) (0.7.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from tensorboard>=1.15->mlagents==0.31.0.dev0) (2.21.0)
# Requirement already satisfied: urllib3<2.0 in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=1.15->mlagents==0.31.0.dev0) (1.26.16)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=1.15->mlagents==0.31.0.dev0) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=1.15->mlagents==0.31.0.dev0) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=1.15->mlagents==0.31.0.dev0) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=1.15->mlagents==0.31.0.dev0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=1.15->mlagents==0.31.0.dev0) (1.3.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from gym>=0.21.0->mlagents_envs==0.31.0.dev0->mlagents==0.31.0.dev0) (0.0.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from requests->huggingface_hub>=0.14->mlagents==0.31.0.dev0) (3.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from requests->huggingface_hub>=0.14->mlagents==0.31.0.dev0) (2023.5.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from requests->huggingface_hub>=0.14->mlagents==0.31.0.dev0) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard>=1.15->mlagents==0.31.0.dev0) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=1.15->mlagents==0.31.0.dev0) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/raj/repos/HF-DeepRL/.venv/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=1.15->mlagents==0.31.0.dev0) (3.2.2)
# Installing collected packages: mlagents
#   Running setup.py develop for mlagents
# Successfully installed mlagents-0.31.0.dev0

# %%
# !mkdir ./training-envs-executables
# !mkdir ./training-envs-executables/linux

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1YHHLjyj6gaZ3Gemx1hQgqrPgSS2ZhmB5' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1YHHLjyj6gaZ3Gemx1hQgqrPgSS2ZhmB5" -O ./training-envs-executables/linux/SnowballTarget.zip && rm -rf /tmp/cookies.txt
# Out:
# --2023-07-04 18:41:58--  https://docs.google.com/uc?export=download&confirm=t&id=1YHHLjyj6gaZ3Gemx1hQgqrPgSS2ZhmB5
# Resolving docs.google.com (docs.google.com)... 142.250.72.14, 2607:f8b0:400f:802::200e
# Connecting to docs.google.com (docs.google.com)|142.250.72.14|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-14-28-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/u79dm3so10ukq6qmj3eah303d10qmpq4/1688517675000/15803371278684422230/*/1YHHLjyj6gaZ3Gemx1hQgqrPgSS2ZhmB5?e=download&uuid=16e1b063-c9df-4a3b-a627-6593e1b06ece [following]
# Warning: wildcards not supported in HTTP.
# --2023-07-04 18:41:58--  https://doc-14-28-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/u79dm3so10ukq6qmj3eah303d10qmpq4/1688517675000/15803371278684422230/*/1YHHLjyj6gaZ3Gemx1hQgqrPgSS2ZhmB5?e=download&uuid=16e1b063-c9df-4a3b-a627-6593e1b06ece
# Resolving doc-14-28-docs.googleusercontent.com (doc-14-28-docs.googleusercontent.com)... 142.250.72.33, 2607:f8b0:400f:807::2001
# Connecting to doc-14-28-docs.googleusercontent.com (doc-14-28-docs.googleusercontent.com)|142.250.72.33|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35134213 (34M) [application/x-zip-compressed]
# Saving to: ‘./training-envs-executables/linux/SnowballTarget.zip’
#
# ./training-envs-exe 100%[===================>]  33.51M  11.0MB/s    in 3.0s
#
# 2023-07-04 18:42:01 (11.0 MB/s) - ‘./training-envs-executables/linux/SnowballTarget.zip’ saved [35134213/35134213]

# %%
# %%capture
# !unzip -d ./training-envs-executables/linux/ ./training-envs-executables/linux/SnowballTarget.zip

# %%
# !chmod -R 755 ./training-envs-executables/linux/SnowballTarget

# %%
# !mlagents-learn ./config/ppo/SnowballTarget.yaml --env=./training-envs-executables/linux/SnowballTarget/SnowballTarget --run-id="SnowballTarget1" --no-graphics
# Out:
#             ┐  ╖
#         ╓╖╬│╡  ││╬╖╖
#     ╓╖╬│││││┘  ╬│││││╬╖
#  ╖╬│││││╬╜        ╙╬│││││╖╖                               ╗╗╗
#  ╬╬╬╬╖││╦╖        ╖╬││╗╣╣╣╬      ╟╣╣╬    ╟╣╣╣             ╜╜╜  ╟╣╣
#  ╬╬╬╬╬╬╬╬╖│╬╖╖╓╬╪│╓╣╣╣╣╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╒╣╣╖╗╣╣╣╗   ╣╣╣ ╣╣╣╣╣╣ ╟╣╣╖   ╣╣╣
#  ╬╬╬╬┐  ╙╬╬╬╬│╓╣╣╣╝╜  ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╣╙ ╙╣╣╣  ╣╣╣ ╙╟╣╣╜╙  ╫╣╣  ╟╣╣
#  ╬╬╬╬┐     ╙╬╬╣╣      ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣     ╣╣╣┌╣╣╜
#  ╬╬╬╜       ╬╬╣╣      ╙╝╣╣╬      ╙╣╣╣╗╖╓╗╣╣╣╜ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣╦╓    ╣╣╣╣╣
#  ╙   ╓╦╖    ╬╬╣╣   ╓╗╗╖            ╙╝╣╣╣╣╝╜   ╘╝╝╜   ╝╝╝  ╝╝╝   ╙╣╣╣    ╟╣╣╣
#    ╩╬╬╬╬╬╬╦╦╬╬╣╣╗╣╣╣╣╣╣╣╝                                             ╫╣╣╣╣
#       ╙╬╬╬╬╬╬╬╣╣╣╣╣╣╝╜
#           ╙╬╬╬╣╣╣╜
#              ╙
#
#  Version information:
#   ml-agents: 0.31.0.dev0,
#   ml-agents-envs: 0.31.0.dev0,
#   Communicator API: 1.5.0,
#   PyTorch: 1.11.0+cu113
# [INFO] Connected to Unity environment with package version 2.1.0-exp.1 and communication version 1.5.0
# [INFO] Connected new brain: SnowballTarget?team=0
# [INFO] Hyperparameters for behavior name SnowballTarget:
# 	trainer_type:	ppo
# 	hyperparameters:
# 	  batch_size:	128
# 	  buffer_size:	2048
# 	  learning_rate:	0.0003
# 	  beta:	0.005
# 	  epsilon:	0.2
# 	  lambd:	0.95
# 	  num_epoch:	3
# 	  shared_critic:	False
# 	  learning_rate_schedule:	linear
# 	  beta_schedule:	linear
# 	  epsilon_schedule:	linear
# 	checkpoint_interval:	50000
# 	network_settings:
# 	  normalize:	False
# 	  hidden_units:	256
# 	  num_layers:	2
# 	  vis_encode_type:	simple
# 	  memory:	None
# 	  goal_conditioning_type:	hyper
# 	  deterministic:	False
# 	reward_signals:
# 	  extrinsic:
# 	    gamma:	0.99
# 	    strength:	1.0
# 	    network_settings:
# 	      normalize:	False
# 	      hidden_units:	128
# 	      num_layers:	2
# 	      vis_encode_type:	simple
# 	      memory:	None
# 	      goal_conditioning_type:	hyper
# 	      deterministic:	False
# 	init_path:	None
# 	keep_checkpoints:	10
# 	even_checkpoints:	False
# 	max_steps:	200000
# 	time_horizon:	64
# 	summary_freq:	10000
# 	threaded:	True
# 	self_play:	None
# 	behavioral_cloning:	None
# [INFO] SnowballTarget. Step: 10000. Time Elapsed: 14.946 s. Mean Reward: 3.841. Std of Reward: 2.110. Training.
# [INFO] SnowballTarget. Step: 20000. Time Elapsed: 28.553 s. Mean Reward: 6.473. Std of Reward: 2.859. Training.
# [INFO] SnowballTarget. Step: 30000. Time Elapsed: 40.651 s. Mean Reward: 8.341. Std of Reward: 3.126. Training.
# [INFO] SnowballTarget. Step: 40000. Time Elapsed: 54.564 s. Mean Reward: 11.073. Std of Reward: 2.947. Training.
# [INFO] SnowballTarget. Step: 50000. Time Elapsed: 66.822 s. Mean Reward: 13.977. Std of Reward: 2.701. Training.
# [INFO] Exported results/SnowballTarget1/SnowballTarget/SnowballTarget-49936.onnx
# [INFO] SnowballTarget. Step: 60000. Time Elapsed: 80.239 s. Mean Reward: 14.600. Std of Reward: 2.793. Training.
# [INFO] SnowballTarget. Step: 70000. Time Elapsed: 93.172 s. Mean Reward: 15.909. Std of Reward: 2.512. Training.
# [INFO] SnowballTarget. Step: 80000. Time Elapsed: 106.928 s. Mean Reward: 17.200. Std of Reward: 2.631. Training.
# [INFO] SnowballTarget. Step: 90000. Time Elapsed: 119.409 s. Mean Reward: 18.705. Std of Reward: 2.555. Training.
# [INFO] SnowballTarget. Step: 100000. Time Elapsed: 133.113 s. Mean Reward: 19.455. Std of Reward: 2.507. Training.
# [INFO] Exported results/SnowballTarget1/SnowballTarget/SnowballTarget-99960.onnx
# [INFO] SnowballTarget. Step: 110000. Time Elapsed: 146.876 s. Mean Reward: 20.481. Std of Reward: 2.132. Training.
# [INFO] SnowballTarget. Step: 120000. Time Elapsed: 159.209 s. Mean Reward: 20.711. Std of Reward: 2.604. Training.
# [INFO] SnowballTarget. Step: 130000. Time Elapsed: 172.778 s. Mean Reward: 21.873. Std of Reward: 2.141. Training.
# [INFO] SnowballTarget. Step: 140000. Time Elapsed: 185.070 s. Mean Reward: 22.432. Std of Reward: 2.071. Training.
# [INFO] SnowballTarget. Step: 150000. Time Elapsed: 198.730 s. Mean Reward: 21.964. Std of Reward: 2.343. Training.
# [INFO] Exported results/SnowballTarget1/SnowballTarget/SnowballTarget-149984.onnx
# [INFO] SnowballTarget. Step: 160000. Time Elapsed: 211.726 s. Mean Reward: 22.818. Std of Reward: 2.279. Training.
# [INFO] SnowballTarget. Step: 170000. Time Elapsed: 224.985 s. Mean Reward: 23.291. Std of Reward: 1.713. Training.
# [INFO] SnowballTarget. Step: 180000. Time Elapsed: 237.971 s. Mean Reward: 22.932. Std of Reward: 2.615. Training.
# [INFO] SnowballTarget. Step: 190000. Time Elapsed: 251.805 s. Mean Reward: 23.200. Std of Reward: 2.084. Training.
# [INFO] SnowballTarget. Step: 200000. Time Elapsed: 264.265 s. Mean Reward: 23.318. Std of Reward: 2.213. Training.
# [INFO] Exported results/SnowballTarget1/SnowballTarget/SnowballTarget-199984.onnx
# [INFO] Exported results/SnowballTarget1/SnowballTarget/SnowballTarget-200112.onnx
# [INFO] Copied results/SnowballTarget1/SnowballTarget/SnowballTarget-200112.onnx to results/SnowballTarget1/SnowballTarget.onnx.

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# !mlagents-push-to-hf --run-id="SnowballTarget1" --local-dir="./results/SnowballTarget1" --repo-id="RajkNakka/ppo-SnowballTarget" --commit-message="First Push"
# Out:
# [INFO] This function will create a model card and upload your SnowballTarget1 into HuggingFace Hub. This is a work in progress: If you encounter a bug, please send open an issue
# [INFO] Pushing repo SnowballTarget1 to the Hugging Face Hub
# SnowballTarget-149984.onnx:   0%|                    | 0.00/647k [00:00<?, ?B/s]
#
# SnowballTarget-149984.pt:   0%|                     | 0.00/3.84M [00:00<?, ?B/s]
# SnowballTarget.onnx:   0%|                           | 0.00/647k [00:00<?, ?B/s]
#
#
#
# SnowballTarget.onnx:   0%|                           | 0.00/647k [00:00<?, ?B/s]
#
#
# Upload 13 LFS files:   0%|                               | 0/13 [00:00<?, ?it/s]
#
#
#
#
# SnowballTarget-149984.onnx:   1%|▏          | 8.19k/647k [00:00<00:58, 10.9kB/s]
#
# SnowballTarget-149984.pt:   0%|            | 8.19k/3.84M [00:00<06:01, 10.6kB/s]
#
#
#
# SnowballTarget.onnx:   1%|▏                 | 8.19k/647k [00:00<01:03, 10.1kB/s]
#
#
#
#
# SnowballTarget-199984.pt:   0%|            | 8.19k/3.84M [00:00<06:22, 10.0kB/s]
# SnowballTarget-149984.onnx:  33%|████▎        | 213k/647k [00:00<00:01, 322kB/s]
#
# SnowballTarget-149984.pt:   6%|▊             | 213k/3.84M [00:00<00:11, 321kB/s]
#
#
#
# SnowballTarget.onnx:  28%|█████▌              | 180k/647k [00:00<00:01, 258kB/s]
# SnowballTarget.onnx:  33%|██████▌             | 213k/647k [00:00<00:01, 305kB/s]
#
#
#
#
# SnowballTarget-149984.onnx:  81%|██████████▌  | 524k/647k [00:00<00:00, 813kB/s]
#
# SnowballTarget-149984.pt:  14%|█▉            | 524k/3.84M [00:01<00:04, 770kB/s]
#
#
#
# SnowballTarget.onnx:  76%|███████████████▏    | 492k/647k [00:01<00:00, 705kB/s]
# SnowballTarget.onnx:  72%|██████████████▍     | 467k/647k [00:01<00:00, 604kB/s]
#
#
#
#
# SnowballTarget-199984.pt:  11%|█▌            | 434k/3.84M [00:01<00:05, 586kB/s]
#
# SnowballTarget-149984.pt:  21%|██▋          | 795k/3.84M [00:01<00:02, 1.09MB/s]
#
#
#
#
# SnowballTarget-199984.pt:  17%|██▎           | 647k/3.84M [00:01<00:04, 712kB/s]
#
# SnowballTarget-149984.onnx: 100%|█████████████| 647k/647k [00:01<00:00, 470kB/s]
#
#
#
#
#
# SnowballTarget-199984.pt:  23%|███▎          | 893k/3.84M [00:01<00:03, 886kB/s]
#
# SnowballTarget.onnx: 100%|████████████████████| 647k/647k [00:01<00:00, 394kB/s]
#
#
#
#
#
# SnowballTarget-199984.pt:  30%|███▌        | 1.14M/3.84M [00:01<00:02, 1.11MB/s]
#
#
# SnowballTarget.onnx: 100%|████████████████████| 647k/647k [00:01<00:00, 375kB/s]
#
#
# SnowballTarget-149984.pt:  59%|███████     | 2.27M/3.84M [00:01<00:00, 2.24MB/s]
#
#
#
#
# SnowballTarget-199984.pt:  36%|████▎       | 1.38M/3.84M [00:01<00:01, 1.27MB/s]
# checkpoint.pt:  28%|██████▎                | 1.06M/3.84M [00:00<00:00, 6.56MB/s]
#
# SnowballTarget-149984.pt:  70%|████████▍   | 2.70M/3.84M [00:01<00:00, 2.25MB/s]
#
#
#
# checkpoint.pt:  45%|██████████▎            | 1.73M/3.84M [00:00<00:00, 5.07MB/s]
#
#
#
#
# SnowballTarget-199984.pt:  44%|█████▎      | 1.69M/3.84M [00:02<00:01, 1.26MB/s]
#
# checkpoint.pt:  58%|█████████████▍         | 2.24M/3.84M [00:00<00:00, 3.03MB/s]
#
#
#
#
# SnowballTarget-199984.pt:  52%|██████▏     | 2.00M/3.84M [00:02<00:01, 1.15MB/s]
#
# checkpoint.pt:  71%|████████████████▎      | 2.72M/3.84M [00:01<00:00, 1.93MB/s]
#
#
#
#
# SnowballTarget-199984.pt:  60%|███████▊     | 2.30M/3.84M [00:02<00:01, 941kB/s]
#
#
#
# SnowballTarget-49936.onnx: 100%|██████████████| 647k/647k [00:01<00:00, 572kB/s]
# checkpoint.pt:  87%|███████████████████▉   | 3.33M/3.84M [00:01<00:00, 2.14MB/s]
#
#
#
#
# SnowballTarget-199984.pt:  69%|████████▎   | 2.67M/3.84M [00:03<00:01, 1.12MB/s]
# SnowballTarget-149984.pt: 100%|████████████| 3.84M/3.84M [00:03<00:00, 1.11MB/s]
#
#
#
#
#
# SnowballTarget-199984.pt:  79%|██████████▎  | 3.04M/3.84M [00:03<00:00, 907kB/s]
#
#
# Upload 13 LFS files:  15%|███▌                   | 2/13 [00:03<00:20,  1.86s/it]
#
# SnowballTarget-99960.onnx: 100%|██████████████| 647k/647k [00:00<00:00, 980kB/s]
#
#
#
#
# SnowballTarget-49936.pt:  21%|███▏           | 819k/3.84M [00:01<00:07, 402kB/s]
# checkpoint.pt:   0%|                                | 0.00/3.84M [00:00<?, ?B/s]
# checkpoint.pt:  20%|████▊                   | 762k/3.84M [00:00<00:01, 2.67MB/s]
#
#
#
#
# SnowballTarget-199984.pt:  89%|███████████▌ | 3.41M/3.84M [00:04<00:00, 741kB/s]
#
#
#
# SnowballTarget-49936.pt:  26%|███▉           | 999k/3.84M [00:02<00:07, 384kB/s]
# checkpoint.pt:  28%|██████▍                | 1.07M/3.84M [00:00<00:01, 1.98MB/s]
#
# checkpoint.pt: 100%|███████████████████████| 3.84M/3.84M [00:02<00:00, 1.32MB/s]
#
# events.out.tfevents.1688518278.snowflake.5236.0:   0%| | 0.00/23.9k [00:00<?, ?B
#
#
#
# SnowballTarget-49936.pt:  31%|████▎         | 1.19M/3.84M [00:02<00:06, 404kB/s]
# checkpoint.pt:  42%|█████████▋             | 1.62M/3.84M [00:00<00:01, 1.61MB/s]
#
#
#
#
# events.out.tfevents.1688518278.snowflake.5236.0: 100%|█| 23.9k/23.9k [00:00<00:0
#
# SnowballTarget.onnx:   0%|                           | 0.00/647k [00:00<?, ?B/s]
#
# SnowballTarget-99960.pt:  56%|███████▎     | 2.17M/3.84M [00:01<00:01, 1.50MB/s]
#
#
#
# SnowballTarget-49936.pt:  36%|████▉         | 1.37M/3.84M [00:03<00:05, 426kB/s]
# checkpoint.pt:  56%|████████████▉          | 2.17M/3.84M [00:01<00:01, 1.48MB/s]
# checkpoint.pt:  65%|██████████████▊        | 2.48M/3.84M [00:01<00:00, 1.58MB/s]
#
#
#
# SnowballTarget-49936.pt:  40%|█████▋        | 1.56M/3.84M [00:03<00:04, 471kB/s]
# checkpoint.pt:  72%|████████████████▋      | 2.79M/3.84M [00:01<00:00, 1.59MB/s]
#
# SnowballTarget-99960.pt:  71%|█████████▏   | 2.72M/3.84M [00:01<00:00, 1.31MB/s]
#
#
#
# SnowballTarget-49936.pt:  45%|██████▎       | 1.74M/3.84M [00:03<00:04, 517kB/s]
# SnowballTarget.onnx: 100%|████████████████████| 647k/647k [00:00<00:00, 895kB/s]
# SnowballTarget-199984.pt: 100%|█████████████| 3.84M/3.84M [00:05<00:00, 662kB/s]
#
# checkpoint.pt:  87%|███████████████████▉   | 3.34M/3.84M [00:02<00:00, 1.64MB/s]
#
#
#
# SnowballTarget-49936.pt:  50%|███████       | 1.93M/3.84M [00:04<00:03, 566kB/s]
#
# SnowballTarget-99960.pt:  85%|███████████  | 3.28M/3.84M [00:02<00:00, 1.29MB/s]
#
#
# Upload 13 LFS files:  31%|███████                | 4/13 [00:06<00:12,  1.43s/it]
# checkpoint.pt:  95%|█████████████████████▊ | 3.65M/3.84M [00:02<00:00, 1.70MB/s]
#
#
#
# SnowballTarget-49936.pt:  55%|███████▋      | 2.11M/3.84M [00:04<00:02, 624kB/s]
#
#
#
# SnowballTarget-49936.pt:  60%|████████▎     | 2.29M/3.84M [00:04<00:02, 678kB/s]
#
# checkpoint.pt: 100%|███████████████████████| 3.84M/3.84M [00:02<00:00, 1.45MB/s]
#
#
#
#
# SnowballTarget-49936.pt:  64%|█████████     | 2.47M/3.84M [00:04<00:01, 756kB/s]
#
#
#
# SnowballTarget-49936.pt:  69%|█████████▋    | 2.66M/3.84M [00:04<00:01, 787kB/s]
#
#
#
# SnowballTarget-49936.pt:  74%|██████████▎   | 2.84M/3.84M [00:05<00:01, 848kB/s]
#
#
#
# SnowballTarget-99960.pt: 100%|█████████████| 3.84M/3.84M [00:03<00:00, 1.08MB/s]
#
#
#
#
# SnowballTarget-49936.pt:  84%|███████████▋  | 3.21M/3.84M [00:05<00:00, 949kB/s]
#
#
#
# SnowballTarget-49936.pt:  88%|████████████▎ | 3.39M/3.84M [00:05<00:00, 984kB/s]
#
#
#
# SnowballTarget-49936.pt:  93%|████████████ | 3.58M/3.84M [00:05<00:00, 1.02MB/s]
#
#
#
# SnowballTarget-49936.pt: 100%|██████████████| 3.84M/3.84M [00:06<00:00, 607kB/s]
#
#
#
# Upload 13 LFS files: 100%|██████████████████████| 13/13 [00:08<00:00,  1.54it/s]
# [INFO] Your model is pushed to the hub. You can view your model here: https://huggingface.co/RajkNakka/ppo-SnowballTarget
